# %% [markdown]
# <a href="https://colab.research.google.com/github/mauro9318/python-numpy-pandas/blob/main/reestructuracion_de_datos_pivot_y_reshape_en_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Las PIVOT TABLES son una herramienta que permite resumir y reorganizar columnas de datos crudos. Con esta herramienta se puede realizar calculos estadísticos sencillos como sumas, promedios y conteos.

# %%
import pandas as pd
sale_data = pd.read_csv("/content/Online_Retail.csv", encoding='latin-1')
sale_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# 2  12/1/10 8:26       2.75     17850.0  United Kingdom
# 3  12/1/10 8:26       3.39     17850.0  United Kingdom
# 4  12/1/10 8:26       3.39     17850.0  United Kingdom

# %%
#creación de una PIVOT TABLE
pivot_table = pd.pivot_table(sale_data, values='Quantity', index='Country', columns='StockCode', aggfunc='sum')
print(pivot_table)
# Out:
# StockCode             10002  10080  10120  10123C  10123G  10124A  10124G  \
# Country
# Australia               NaN    NaN    NaN     NaN     NaN     NaN     NaN
# Austria                 NaN    NaN    NaN     NaN     NaN     NaN     NaN
# Bahrain                 NaN    NaN    NaN     NaN     NaN     NaN     NaN
# Belgium                 NaN    NaN    NaN     NaN     NaN     NaN     NaN
# Brazil                  NaN    NaN    NaN     NaN     NaN     NaN     NaN
# Canada                  NaN    NaN    NaN     NaN     NaN     NaN     NaN
# Channel Islands         NaN    NaN    NaN     NaN     NaN     NaN     NaN
# Cyprus                  NaN    NaN    NaN     NaN     NaN     NaN     NaN
# Czech Republic          NaN    NaN    NaN     NaN     NaN     NaN     NaN
# Denmark                 NaN    NaN    NaN     NaN     NaN     NaN     NaN
# EIRE                   12.0    NaN    NaN     NaN     NaN     NaN     NaN
# ...
